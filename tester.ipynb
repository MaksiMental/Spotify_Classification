# %%
import pandas as pd

df = pd.read_csv('dataset/dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
# Drop unnecessary columns
df = df.drop(columns=['Unnamed: 0'])

# Rename columns to match your existing dataset
df = df.rename(columns={
    'artists': 'artist',
    'album_name': 'album',
    'track_name': 'name',
    'track_genre': 'genre'
})

# %%
df.columns
# Out:
# Index(['track_id', 'artist', 'album', 'name', 'popularity', 'duration_ms',
#        'explicit', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'genre'],
#       dtype='object')

# %%
df.head()
# Out:
#                  track_id                  artist  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                                album  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                          name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# ...

# %%
df_danish = pd.read_csv('dataset/spotify_danish.csv')

# %%
df_danish.columns
# Out:
# Index(['Unnamed: 0', 'name', 'album', 'artist', 'release_date', 'length',
#        'popularity', 'danceability', 'acousticness', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
#        'key', 'valence'],
#       dtype='object')

# %%
# Drop unnecessary columns
df_danish = df_danish.drop(columns=['Unnamed: 0', 'release_date', ''length''])

# Rename columns to match your existing dataset
df = df.rename(columns={
    'artists': 'artist',
    'album_name': 'album',
    'track_name': 'name',
    'track_genre': 'genre'
})

# %%
import random

# Load the data from your CSV files
df_danish = pd.read_csv('dataset/spotify_danish.csv')
df_599 = pd.read_csv('dataset/spotify599.csv')

# Append the data from the CSV files to your existing DataFrame
df = df.append(df_danish, ignore_index=True)
df = df.append(df_599, ignore_index=True)

# Generate a new unique ID column
df['id'] = [random.randint(0, 1e5) for _ in range(len(df))]
# Out:
# /var/folders/7f/xrny7_8d32q6xy6nps28xn8m0000gn/T/ipykernel_73286/42114422.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_danish, ignore_index=True)
# /var/folders/7f/xrny7_8d32q6xy6nps28xn8m0000gn/T/ipykernel_73286/42114422.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df_599, ignore_index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114650 entries, 0 to 114649
# Data columns (total 23 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   artist            114649 non-null  object
#  1   album             114649 non-null  object
#  2   name              114649 non-null  object
#  3   popularity        114650 non-null  int64
#  4   duration_ms       114000 non-null  float64
#  5   explicit          114000 non-null  object
#  6   danceability      114650 non-null  float64
#  7   energy            114650 non-null  float64
#  8   key               114650 non-null  int64
#  9   loudness          114650 non-null  float64
#  10  mode              114000 non-null  float64
#  11  speechiness       114650 non-null  float64
#  12  acousticness      114650 non-null  float64
#  13  instrumentalness  114650 non-null  float64
#  14  liveness          114650 non-null  float64
# ...

# %%
df.head()
# Out:
#                    artist                                              album  \
# 0             Gen Hoshino                                             Comedy
# 1            Ben Woodward                                   Ghost (Acoustic)
# 2  Ingrid Michaelson;ZAYN                                     To Begin Again
# 3            Kina Grannis  Crazy Rich Asians (Original Motion Picture Sou...
# 4        Chord Overstreet                                            Hold On
#
#                          name  popularity  duration_ms explicit  danceability  \
# 0                      Comedy          73     230666.0    False         0.676
# 1            Ghost - Acoustic          55     149610.0    False         0.420
# 2              To Begin Again          57     210826.0    False         0.438
# 3  Can't Help Falling In Love          71     201933.0    False         0.266
# 4                     Hold On          82     198853.0    False         0.618
#
# ...
