# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('dataset.csv')

# %% [markdown]
# # fix chris brown

# %%
df_chris = pd.read_csv('spotify_chrisbrown.csv')

# %%
df_chris['genre'].value_counts()
# Out:
# ['r&b', 'rap']                                                                                                                             70
# []                                                                                                                                          4
# ['hip hop', 'miami hip hop', 'pop rap', 'rap']                                                                                              2
# ['boston hip hop', 'hip hop', 'pop rap', 'rap']                                                                                             2
# ['brooklyn drill', 'rap']                                                                                                                   1
# ['bronx hip hop', 'east coast hip hop', 'gangster rap', 'hardcore hip hop', 'hip hop', 'pop rap', 'rap', 'trap']                            1
# ...

# %%
df_chris['genre'] = 'rap'

# %%
df_chris
# Out:
#     Unnamed: 0                track_id  \
# 0            0  3XqM8hLCEYlbnFjoWwqtFv
# 1            1  5AeEH69Mp87Zx3wNmyeAK0
# 2            2  3NZJlJemX3mzjf56MqC5ML
# 3            3  5IgjP7X4th6nMNDh4akUHb
# 4            4  4i1wik8DtU7eqSEWRsTHuP
# ..         ...                     ...
# 94          94  0fgZUSa7D7aVvv3GfO0A1n
# 95          95  0hy1SOTEn9ifXTzOwnCwEr
# 96          96  2lD4LsB3iQVnddkVM2RFAl
# 97          97  3Rh3zDYanZFHaeXFT4Asps
# 98          98  6g8vNyogMW32lhHlNcDiwX
#
#                                                  name  \
# 0                            Angel Numbers / Ten Toes
# 1                                           Bruce Lee
# 2                                             Forever
# 3                                 Under The Influence
# 4                                          Delusional
# ..                                                ...
# 94        Post to Be (feat. Chris Brown & Jhene Aiko)
# ...

# %% [markdown]
# # fix country

# %%
df_country = pd.read_csv('spotify_country.csv')

# %%
df_country['genre'].value_counts()
# Out:
# ['contemporary country', 'country', 'country road', 'modern country rock']                            34
# ['contemporary country', 'modern country pop']                                                        15
# ['contemporary country', 'country', 'country road']                                                   11
# ['contemporary country']                                                                               8
# ['contemporary country', 'country']                                                                    5
# ['modern country pop']                                                                                 3
# ['classic texas country', 'contemporary country', 'modern country pop']                                3
# ['contemporary country', 'country road', 'modern country pop', 'modern country rock']                  3
# ['contemporary country', 'country', 'country pop', 'country road', 'modern country rock']              3
# ...

# %%
df_country['genre'] = 'contemporary country'

# %%
df_country.head()
# Out:
#    Unnamed: 0                track_id  \
# 0           0  4KULAymBBJcPRpk1yO4dOG
# 1           1  0eBFgRxyVSeuT4iyrbukdn
# 2           2  5ya0TmUQw2wHMkq36rPsnd
# 3           3  6vsa5VDsIaWC8oJnowU65l
# 4           4  02FAxAwzApe6pAqfAL3dLr
#
#                                             name  \
# 0  I Remember Everything (feat. Kacey Musgraves)
# 1                      Where the Wild Things Are
# 2                                  World on Fire
# 3                This Town's Been Too Good To Us
# 4                              All I Need Is You
#
#                              album        artist  popularity  danceability  \
# 0                       Zach Bryan    Zach Bryan          91         0.429
# 1                      Gettin' Old    Luke Combs          86         0.708
# 2              NATE SMITH (DELUXE)    Nate Smith          76         0.461
# 3  This Town's Been Too Good To Us   Dylan Scott          73         0.696
# ...

# %%
df_dansk = pd.read_csv('danish_hitlist_songs_with_genres.csv')

# %%
df_dansk.head()
# Out:
#                  track_id                name                      album  \
# 0  7129iqBafaphfc3WPCGC0L             7 Years  Lukas Graham (Blue Album)
# 1  5qaaQp6KvkEdB2q7SKQAcJ     ErruDumEllaHvad            ErruDumEllaHvad
# 2  1UGQZb5PNV9GorC9NVmNYs  Når Et Lys Slukkes           3: Fresh-Fri-Fly
# 3  0JFhEbH1Ij9BIrO800IEIK              Orange                     Orange
# 4  1NgeW6kFhdqAvEKgKYhf1s               Paris                      Paris
#
#     artist_name  popularity           genre  danceability  energy  key  \
# 0  Lukas Graham          52      danish pop         0.742   0.479   10
# 1       ICEKIID          54  danish hip hop         0.922   0.708    8
# 2     Nik & Jay          39      danish pop         0.630   0.800    2
# 3  Tobias Rahim          50      danish pop         0.681   0.493    9
# 4     Lord Siva          45  danish hip hop         0.818   0.533    6
#
#    loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# ...

# %%
df_dansk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1570 entries, 0 to 1569
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          1570 non-null   object
#  1   name              1570 non-null   object
#  2   album             1570 non-null   object
#  3   artist_name       1570 non-null   object
#  4   popularity        1570 non-null   int64
#  5   genre             1570 non-null   object
#  6   danceability      1570 non-null   float64
#  7   energy            1570 non-null   float64
#  8   key               1570 non-null   int64
#  9   loudness          1570 non-null   float64
#  10  mode              1570 non-null   int64
#  11  speechiness       1570 non-null   float64
#  12  acousticness      1570 non-null   float64
#  13  instrumentalness  1570 non-null   float64
#  14  liveness          1570 non-null   float64
#  15  valence           1570 non-null   float64
# ...
